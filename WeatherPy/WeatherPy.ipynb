# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 610

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
url = "http://api.openweathermap.org/data/2.5/weather?"

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
#print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = f'https://api.openweathermap.org/data/2.5/weather?q={city}&appid={weather_api_key}'
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_date = city_weather["dt"]

        # Append the City information into city_data list
        city_data.append({"City": city, 
                           "Lat": city_lat, 
                           "Lng": city_lng, 
                           "Max Temp": city_max_temp,
                           "Humidity": city_humidity,
                           "Cloudiness": city_clouds,
                           "Wind Speed": city_wind,
                           "Country": city_country,
                           "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# Processing Record 1 of Set 1 | keflavik
# Processing Record 2 of Set 1 | bredasdorp
# Processing Record 3 of Set 1 | albany
# Processing Record 4 of Set 1 | saipan
# Processing Record 5 of Set 1 | college
# Processing Record 6 of Set 1 | udachny
# Processing Record 7 of Set 1 | banjarmasin
# Processing Record 8 of Set 1 | danville
# Processing Record 9 of Set 1 | nikolayevsk-on-amure
# Processing Record 10 of Set 1 | port elizabeth
# Processing Record 11 of Set 1 | lodwar
# Processing Record 12 of Set 1 | port-aux-francais
# Processing Record 13 of Set 1 | petropavlovsk-kamchatsky
# Processing Record 14 of Set 1 | grytviken
# Processing Record 15 of Set 1 | tranovaho
# City not found. Skipping...
# Processing Record 16 of Set 1 | jamestown
# Processing Record 17 of Set 1 | howard springs
# Processing Record 18 of Set 1 | kapuskasing
# Processing Record 19 of Set 1 | edinburgh of the seven seas
# Processing Record 20 of Set 1 | yellowknife
# Processing Record 21 of Set 1 | alto araguaia
# Processing Record 22 of Set 1 | ribeira grande
# Processing Record 23 of Set 1 | iqaluit
# Processing Record 24 of Set 1 | sechura
# Processing Record 25 of Set 1 | kulhudhuffushi
# Processing Record 26 of Set 1 | zouerate
# Processing Record 27 of Set 1 | queenstown
# Processing Record 28 of Set 1 | mongo
# Processing Record 29 of Set 1 | hithadhoo
# Processing Record 30 of Set 1 | bilibino
# Processing Record 31 of Set 1 | ilulissat
# Processing Record 32 of Set 1 | anadyr
# Processing Record 33 of Set 1 | novyy urengoy
# Processing Record 34 of Set 1 | blackmans bay
# Processing Record 35 of Set 1 | geraldton
# Processing Record 36 of Set 1 | vilyuchinsk
# Processing Record 37 of Set 1 | 'ohonua
# City not found. Skipping...
# Processing Record 38 of Set 1 | lebu
# Processing Record 39 of Set 1 | hihifo
# City not found. Skipping...
# Processing Record 40 of Set 1 | vorkuta
# Processing Record 41 of Set 1 | valparaiso
# Processing Record 42 of Set 1 | basco
# Processing Record 43 of Set 1 | wenchang
# Processing Record 44 of Set 1 | avarua
# Processing Record 45 of Set 1 | angaur state
# Processing Record 46 of Set 1 | adamstown
# Processing Record 47 of Set 1 | mili
# Processing Record 48 of Set 1 | bethel
# Processing Record 49 of Set 1 | longyearbyen
# Processing Record 50 of Set 1 | kargasok
# Processing Record 0 of Set 2 | mishkino
# Processing Record 1 of Set 2 | hamilton
# Processing Record 2 of Set 2 | yanchep
# Processing Record 3 of Set 2 | port alfred
# Processing Record 4 of Set 2 | pyapon
# Processing Record 5 of Set 2 | praia da vitoria
# Processing Record 6 of Set 2 | taiohae
# City not found. Skipping...
# Processing Record 7 of Set 2 | flying fish cove
# Processing Record 8 of Set 2 | al khaburah
# Processing Record 9 of Set 2 | tabuk
# Processing Record 10 of Set 2 | port mathurin
# Processing Record 11 of Set 2 | sideropolis
# Processing Record 12 of Set 2 | papatowai
# Processing Record 13 of Set 2 | san jose de jachal
# Processing Record 14 of Set 2 | al jawf
# Processing Record 15 of Set 2 | egilsstadir
# Processing Record 16 of Set 2 | puerto ayora
# Processing Record 17 of Set 2 | san patricio
# Processing Record 18 of Set 2 | west island
# Processing Record 19 of Set 2 | chhor
# Processing Record 20 of Set 2 | hermanus
# Processing Record 21 of Set 2 | georgetown
# Processing Record 22 of Set 2 | yabassi
# Processing Record 23 of Set 2 | weno
# Processing Record 24 of Set 2 | phan rang-thap cham
# Processing Record 25 of Set 2 | san vicente
# Processing Record 26 of Set 2 | betong
# Processing Record 27 of Set 2 | guiuan
# Processing Record 28 of Set 2 | betio village
# Processing Record 29 of Set 2 | callao
# Processing Record 30 of Set 2 | itaituba
# Processing Record 31 of Set 2 | uturoa
# Processing Record 32 of Set 2 | new norfolk
# Processing Record 33 of Set 2 | selfoss
# Processing Record 34 of Set 2 | taoudenni
# Processing Record 35 of Set 2 | aasiaat
# Processing Record 36 of Set 2 | qaqortoq
# Processing Record 37 of Set 2 | talnakh
# Processing Record 38 of Set 2 | ribeira brava
# Processing Record 39 of Set 2 | luanda
# Processing Record 40 of Set 2 | nuuk
# Processing Record 41 of Set 2 | durban
# Processing Record 42 of Set 2 | latakia
# Processing Record 43 of Set 2 | invercargill
# Processing Record 44 of Set 2 | hadibu
# Processing Record 45 of Set 2 | lihue
# Processing Record 46 of Set 2 | elliot lake
# Processing Record 47 of Set 2 | ponta delgada
# Processing Record 48 of Set 2 | tiksi
# Processing Record 49 of Set 2 | paredon
# Processing Record 0 of Set 3 | enewetak
# Processing Record 1 of Set 3 | velikiy ustyug
# Processing Record 2 of Set 3 | merizo village
# Processing Record 3 of Set 3 | palikir - national government center
# Processing Record 4 of Set 3 | ashland
# Processing Record 5 of Set 3 | yeppoon
# Processing Record 6 of Set 3 | kupino
# Processing Record 7 of Set 3 | lucea
# Processing Record 8 of Set 3 | ola
# Processing Record 9 of Set 3 | iskateley
# Processing Record 10 of Set 3 | greymouth
# Processing Record 11 of Set 3 | sitka
# Processing Record 12 of Set 3 | guarapuava
# Processing Record 13 of Set 3 | st. john's
# Processing Record 14 of Set 3 | walvis bay
# Processing Record 15 of Set 3 | westport
# Processing Record 16 of Set 3 | bairnsdale
# Processing Record 17 of Set 3 | puerto natales
# Processing Record 18 of Set 3 | waitangi
# Processing Record 19 of Set 3 | isafjordur
# Processing Record 20 of Set 3 | point pedro
# Processing Record 21 of Set 3 | fort mcmurray
# Processing Record 22 of Set 3 | sun city west
# Processing Record 23 of Set 3 | fale old settlement
# Processing Record 24 of Set 3 | yarmouth
# Processing Record 25 of Set 3 | afaahiti
# Processing Record 26 of Set 3 | cabo san lucas
# Processing Record 27 of Set 3 | pisco
# Processing Record 28 of Set 3 | vorgashor
# Processing Record 29 of Set 3 | isangel
# Processing Record 30 of Set 3 | muroto-misakicho
# Processing Record 31 of Set 3 | konarka
# Processing Record 32 of Set 3 | at taj
# Processing Record 33 of Set 3 | kuytun
# Processing Record 34 of Set 3 | luderitz
# Processing Record 35 of Set 3 | baldoyle
# Processing Record 36 of Set 3 | ulladulla
# Processing Record 37 of Set 3 | kodiak
# Processing Record 38 of Set 3 | nacozari de garcia
# Processing Record 39 of Set 3 | sao vicente
# Processing Record 40 of Set 3 | montepuez
# Processing Record 41 of Set 3 | tazovsky
# Processing Record 42 of Set 3 | wailua homesteads
# Processing Record 43 of Set 3 | sinabang
# Processing Record 44 of Set 3 | igrim
# Processing Record 45 of Set 3 | ban bueng
# Processing Record 46 of Set 3 | hawaiian paradise park
# Processing Record 47 of Set 3 | totness
# Processing Record 48 of Set 3 | canico
# Processing Record 49 of Set 3 | kingston
# Processing Record 0 of Set 4 | olonkinbyen
# Processing Record 1 of Set 4 | tenosique
# Processing Record 2 of Set 4 | minas de marcona
# Processing Record 3 of Set 4 | tolanaro
# Processing Record 4 of Set 4 | susuman
# Processing Record 5 of Set 4 | valozhyn
# Processing Record 6 of Set 4 | seven pagodas
# Processing Record 7 of Set 4 | puerto san carlos
# City not found. Skipping...
# Processing Record 8 of Set 4 | yemetsk
# Processing Record 9 of Set 4 | atafu village
# Processing Record 10 of Set 4 | ushuaia
# Processing Record 11 of Set 4 | villa gesell
# Processing Record 12 of Set 4 | novyy rogachik
# Processing Record 13 of Set 4 | priargunsk
# Processing Record 14 of Set 4 | laojunmiao
# Processing Record 15 of Set 4 | borkum
# Processing Record 16 of Set 4 | hammerfest
# Processing Record 17 of Set 4 | havre
# Processing Record 18 of Set 4 | napier
# Processing Record 19 of Set 4 | peabiru
# Processing Record 20 of Set 4 | tsiombe
# Processing Record 21 of Set 4 | jimma
# Processing Record 22 of Set 4 | keokuk
# Processing Record 23 of Set 4 | nkhata bay
# Processing Record 24 of Set 4 | malango
# Processing Record 25 of Set 4 | howrah
# Processing Record 26 of Set 4 | la asuncion
# Processing Record 27 of Set 4 | glace bay
# Processing Record 28 of Set 4 | papao
# Processing Record 29 of Set 4 | cable beach
# City not found. Skipping...
# Processing Record 30 of Set 4 | manaure
# Processing Record 31 of Set 4 | acarau
# Processing Record 32 of Set 4 | gornopravdinsk
# Processing Record 33 of Set 4 | khovd
# Processing Record 34 of Set 4 | utrik
# Processing Record 35 of Set 4 | mankera
# Processing Record 36 of Set 4 | hastings
# Processing Record 37 of Set 4 | manggar
# Processing Record 38 of Set 4 | motueka
# Processing Record 39 of Set 4 | pogradec
# Processing Record 40 of Set 4 | lichtenburg
# Processing Record 41 of Set 4 | north bend
# Processing Record 42 of Set 4 | margaret river
# Processing Record 43 of Set 4 | tura
# Processing Record 44 of Set 4 | summerside
# Processing Record 45 of Set 4 | saint-philippe
# Processing Record 46 of Set 4 | ust-nera
# Processing Record 47 of Set 4 | labrador city
# Processing Record 48 of Set 4 | mount gambier
# Processing Record 49 of Set 4 | port douglas
# Processing Record 0 of Set 5 | tobi village
# City not found. Skipping...
# Processing Record 1 of Set 5 | kataragama
# City not found. Skipping...
# Processing Record 2 of Set 5 | sault ste. marie
# Processing Record 3 of Set 5 | kargil
# Processing Record 4 of Set 5 | miringa
# Processing Record 5 of Set 5 | labytnangi
# Processing Record 6 of Set 5 | karystos
# Processing Record 7 of Set 5 | emerald
# Processing Record 8 of Set 5 | dryden
# Processing Record 9 of Set 5 | ujae
# Processing Record 10 of Set 5 | thunder bay
# Processing Record 11 of Set 5 | kolonia
# Processing Record 12 of Set 5 | rawson
# Processing Record 13 of Set 5 | narasapur
# Processing Record 14 of Set 5 | mossel bay
# Processing Record 15 of Set 5 | shenjiamen
# Processing Record 16 of Set 5 | nuku'alofa
# Processing Record 17 of Set 5 | carnarvon
# Processing Record 18 of Set 5 | okhotsk
# Processing Record 19 of Set 5 | songea
# Processing Record 20 of Set 5 | lionel town
# Processing Record 21 of Set 5 | daru
# Processing Record 22 of Set 5 | kittila
# Processing Record 23 of Set 5 | kupang
# Processing Record 24 of Set 5 | constantia
# Processing Record 25 of Set 5 | domna
# Processing Record 26 of Set 5 | puerto lempira
# Processing Record 27 of Set 5 | lethem
# Processing Record 28 of Set 5 | yuzhno-kurilsk
# Processing Record 29 of Set 5 | hillsboro
# Processing Record 30 of Set 5 | rabo de peixe
# Processing Record 31 of Set 5 | madang
# Processing Record 32 of Set 5 | thompson
# Processing Record 33 of Set 5 | fuvahmulah
# City not found. Skipping...
# Processing Record 34 of Set 5 | tocopilla
# Processing Record 35 of Set 5 | rio preto da eva
# Processing Record 36 of Set 5 | khash
# Processing Record 37 of Set 5 | meadow lake
# Processing Record 38 of Set 5 | bayganin
# Processing Record 39 of Set 5 | kuching
# Processing Record 40 of Set 5 | ancud
# Processing Record 41 of Set 5 | fort bragg
# Processing Record 42 of Set 5 | la'ie
# Processing Record 43 of Set 5 | saudarkrokur
# Processing Record 44 of Set 5 | copala
# Processing Record 45 of Set 5 | guerrero negro
# Processing Record 46 of Set 5 | hassi messaoud
# Processing Record 47 of Set 5 | oeiras do para
# Processing Record 48 of Set 5 | arkhara
# Processing Record 49 of Set 5 | nhamunda
# Processing Record 0 of Set 6 | gunnison
# Processing Record 1 of Set 6 | karratha
# Processing Record 2 of Set 6 | mumford
# Processing Record 3 of Set 6 | yelizovo
# Processing Record 4 of Set 6 | whitehorse
# Processing Record 5 of Set 6 | natal
# Processing Record 6 of Set 6 | margate
# Processing Record 7 of Set 6 | bardai
# Processing Record 8 of Set 6 | nadi
# Processing Record 9 of Set 6 | chonchi
# Processing Record 10 of Set 6 | chilca
# Processing Record 11 of Set 6 | katsuura
# Processing Record 12 of Set 6 | severo-yeniseyskiy
# Processing Record 13 of Set 6 | kawthoung
# City not found. Skipping...
# Processing Record 14 of Set 6 | harper
# Processing Record 15 of Set 6 | stanley
# Processing Record 16 of Set 6 | mbouda
# Processing Record 17 of Set 6 | ciudad lazaro cardenas
# Processing Record 18 of Set 6 | pulaski
# Processing Record 19 of Set 6 | suva
# Processing Record 20 of Set 6 | kavieng
# Processing Record 21 of Set 6 | gaiman
# Processing Record 22 of Set 6 | jutai
# Processing Record 23 of Set 6 | port glaud
# City not found. Skipping...
# Processing Record 24 of Set 6 | alvinopolis
# Processing Record 25 of Set 6 | lompoc
# Processing Record 26 of Set 6 | silifke
# Processing Record 27 of Set 6 | neyriz
# Processing Record 28 of Set 6 | ulaangom
# Processing Record 29 of Set 6 | berdigestyakh
# Processing Record 30 of Set 6 | gueltat zemmour
# City not found. Skipping...
# Processing Record 31 of Set 6 | amorebieta
# Processing Record 32 of Set 6 | tazacorte
# Processing Record 33 of Set 6 | warrnambool
# Processing Record 34 of Set 6 | bamboo flat
# Processing Record 35 of Set 6 | saint-valery-en-caux
# Processing Record 36 of Set 6 | sultanah
# Processing Record 37 of Set 6 | usogorsk
# Processing Record 38 of Set 6 | gilgit
# Processing Record 39 of Set 6 | nishinoomote
# Processing Record 40 of Set 6 | laguna
# Processing Record 41 of Set 6 | haizhou
# Processing Record 42 of Set 6 | boende
# Processing Record 43 of Set 6 | anabar
# City not found. Skipping...
# Processing Record 44 of Set 6 | kalamata
# Processing Record 45 of Set 6 | ahau
# City not found. Skipping...
# Processing Record 46 of Set 6 | genhe
# Processing Record 47 of Set 6 | zyryanskoye
# Processing Record 48 of Set 6 | nadym
# Processing Record 49 of Set 6 | digapahandi
# Processing Record 0 of Set 7 | crane
# Processing Record 1 of Set 7 | sormiou
# City not found. Skipping...
# Processing Record 2 of Set 7 | siwa oasis
# Processing Record 3 of Set 7 | zaraza
# Processing Record 4 of Set 7 | san jose village
# City not found. Skipping...
# Processing Record 5 of Set 7 | as suwayq
# Processing Record 6 of Set 7 | tandalti
# Processing Record 7 of Set 7 | san julian
# Processing Record 8 of Set 7 | salair
# Processing Record 9 of Set 7 | inhambane
# Processing Record 10 of Set 7 | bontang
# Processing Record 11 of Set 7 | lysekil
# Processing Record 12 of Set 7 | izluchinsk
# Processing Record 13 of Set 7 | vila velha
# Processing Record 14 of Set 7 | kone
# Processing Record 15 of Set 7 | hailey
# Processing Record 16 of Set 7 | tangalle
# Processing Record 17 of Set 7 | sinop
# Processing Record 18 of Set 7 | rosetta
# Processing Record 19 of Set 7 | manicore
# Processing Record 20 of Set 7 | la mira
# Processing Record 21 of Set 7 | kutum
# Processing Record 22 of Set 7 | bubaque
# Processing Record 23 of Set 7 | palmer
# Processing Record 24 of Set 7 | labuan
# Processing Record 25 of Set 7 | malvan
# Processing Record 26 of Set 7 | tahmoor
# Processing Record 27 of Set 7 | sonsorol village
# City not found. Skipping...
# Processing Record 28 of Set 7 | hasaki
# Processing Record 29 of Set 7 | woolgoolga
# Processing Record 30 of Set 7 | vorotynsk
# Processing Record 31 of Set 7 | mukah
# City not found. Skipping...
# Processing Record 32 of Set 7 | esfarayen
# Processing Record 33 of Set 7 | hinganghat
# Processing Record 34 of Set 7 | alotau
# City not found. Skipping...
# Processing Record 35 of Set 7 | larreynaga
# Processing Record 36 of Set 7 | necochea
# Processing Record 37 of Set 7 | khandyga
# Processing Record 38 of Set 7 | san antonio de pale
# Processing Record 39 of Set 7 | lezhe
# Processing Record 40 of Set 7 | fort drum
# Processing Record 41 of Set 7 | prieska
# Processing Record 42 of Set 7 | sao jose da coroa grande
# Processing Record 43 of Set 7 | inari
# Processing Record 44 of Set 7 | veraval
# Processing Record 45 of Set 7 | undurkhaan
# Processing Record 46 of Set 7 | al bawiti
# Processing Record 47 of Set 7 | bargara
# City not found. Skipping...
# Processing Record 48 of Set 7 | sarandi del yi
# Processing Record 49 of Set 7 | nemuro
# Processing Record 0 of Set 8 | masterton
# Processing Record 1 of Set 8 | remire-montjoly
# Processing Record 2 of Set 8 | berezovyy
# Processing Record 3 of Set 8 | codrington
# Processing Record 4 of Set 8 | torbat-e heydariyeh
# Processing Record 5 of Set 8 | ketchikan
# Processing Record 6 of Set 8 | veymandoo
# City not found. Skipping...
# Processing Record 7 of Set 8 | constitucion
# Processing Record 8 of Set 8 | katsuren-haebaru
# Processing Record 9 of Set 8 | ta`u
# Processing Record 10 of Set 8 | waingapu
# Processing Record 11 of Set 8 | sabha
# Processing Record 12 of Set 8 | gorontalo
# Processing Record 13 of Set 8 | lospalos
# Processing Record 14 of Set 8 | susanville
# Processing Record 15 of Set 8 | san antonio del estrecho
# City not found. Skipping...
# Processing Record 16 of Set 8 | weston
# Processing Record 17 of Set 8 | mahabe
# City not found. Skipping...
# Processing Record 18 of Set 8 | kindu
# Processing Record 19 of Set 8 | asha
# Processing Record 20 of Set 8 | checker hall
# City not found. Skipping...
# Processing Record 21 of Set 8 | hotan
# Processing Record 22 of Set 8 | port lincoln
# Processing Record 23 of Set 8 | nizhniy lomov
# Processing Record 24 of Set 8 | east london
# Processing Record 25 of Set 8 | sayat
# Processing Record 26 of Set 8 | kill devil hills
# Processing Record 27 of Set 8 | bousso
# Processing Record 28 of Set 8 | kidal
# Processing Record 29 of Set 8 | deland
# Processing Record 30 of Set 8 | ebon
# Processing Record 31 of Set 8 | niimi
# Processing Record 32 of Set 8 | punta arenas
# Processing Record 33 of Set 8 | ilek
# Processing Record 34 of Set 8 | lundazi
# Processing Record 35 of Set 8 | florida
# Processing Record 36 of Set 8 | sovetskaya gavan'
# Processing Record 37 of Set 8 | kapa'a
# Processing Record 38 of Set 8 | irymple
# Processing Record 39 of Set 8 | usinsk
# Processing Record 40 of Set 8 | sassandra
# Processing Record 41 of Set 8 | douz
# Processing Record 42 of Set 8 | tanumah
# Processing Record 43 of Set 8 | lesnikovo
# Processing Record 44 of Set 8 | betare oya
# Processing Record 45 of Set 8 | colonia
# Processing Record 46 of Set 8 | atbasar
# Processing Record 47 of Set 8 | juneau
# Processing Record 48 of Set 8 | kudymkar
# Processing Record 49 of Set 8 | gadzhiyevo
# Processing Record 0 of Set 9 | ngama
# Processing Record 1 of Set 9 | palu
# Processing Record 2 of Set 9 | klyuchi
# Processing Record 3 of Set 9 | alice springs
# Processing Record 4 of Set 9 | nova sintra
# Processing Record 5 of Set 9 | arkhangel'sk
# Processing Record 6 of Set 9 | gantang
# Processing Record 7 of Set 9 | kruisfontein
# Processing Record 8 of Set 9 | ashibetsu
# Processing Record 9 of Set 9 | chiredzi
# Processing Record 10 of Set 9 | kabompo
# Processing Record 11 of Set 9 | mukalla
# Processing Record 12 of Set 9 | maragogi
# Processing Record 13 of Set 9 | kosh-agach
# Processing Record 14 of Set 9 | dunedin
# Processing Record 15 of Set 9 | hilo
# Processing Record 16 of Set 9 | praia
# Processing Record 17 of Set 9 | dudinka
# Processing Record 18 of Set 9 | progreso
# Processing Record 19 of Set 9 | polyarnyy
# Processing Record 20 of Set 9 | puerto lleras
# Processing Record 21 of Set 9 | port shepstone
# Processing Record 22 of Set 9 | coahuayana de hidalgo
# Processing Record 23 of Set 9 | san jose
# Processing Record 24 of Set 9 | tokar
# Processing Record 25 of Set 9 | port augusta
# Processing Record 26 of Set 9 | lazaro cardenas
# Processing Record 27 of Set 9 | tosontsengel
# Processing Record 28 of Set 9 | ust'-barguzin
# Processing Record 29 of Set 9 | rey bouba
# Processing Record 30 of Set 9 | maceio
# Processing Record 31 of Set 9 | northam
# Processing Record 32 of Set 9 | tofol
# Processing Record 33 of Set 9 | bayanhongor
# Processing Record 34 of Set 9 | la passe
# Processing Record 35 of Set 9 | international falls
# Processing Record 36 of Set 9 | puerto carreno
# Processing Record 37 of Set 9 | sao felix do xingu
# Processing Record 38 of Set 9 | solleftea
# Processing Record 39 of Set 9 | bafoulabe
# Processing Record 40 of Set 9 | tonghae
# Processing Record 41 of Set 9 | maymana
# Processing Record 42 of Set 9 | blagodatnoye
# Processing Record 43 of Set 9 | manokwari
# Processing Record 44 of Set 9 | punta del este
# Processing Record 45 of Set 9 | bodo
# Processing Record 46 of Set 9 | saint-joseph
# Processing Record 47 of Set 9 | lorengau
# Processing Record 48 of Set 9 | chipiona
# Processing Record 49 of Set 9 | arraial do cabo
# Processing Record 0 of Set 10 | duong dong
# Processing Record 1 of Set 10 | odienne
# Processing Record 2 of Set 10 | paradera
# City not found. Skipping...
# Processing Record 3 of Set 10 | saint-pierre
# Processing Record 4 of Set 10 | garhi khairo
# Processing Record 5 of Set 10 | peace river
# Processing Record 6 of Set 10 | bikenibeu village
# Processing Record 7 of Set 10 | al hufuf
# Processing Record 8 of Set 10 | waddan
# Processing Record 9 of Set 10 | la ronge
# Processing Record 10 of Set 10 | chhaprauli
# Processing Record 11 of Set 10 | shache
# Processing Record 12 of Set 10 | puerto baquerizo moreno
# Processing Record 13 of Set 10 | kailua-kona
# Processing Record 14 of Set 10 | lyubinskiy
# Processing Record 15 of Set 10 | kasempa
# Processing Record 16 of Set 10 | canete
# Processing Record 17 of Set 10 | aras-asan
# Processing Record 18 of Set 10 | happy valley-goose bay
# Processing Record 19 of Set 10 | izberbash
# Processing Record 20 of Set 10 | falmouth
# Processing Record 21 of Set 10 | rock springs
# Processing Record 22 of Set 10 | solnechniy
# City not found. Skipping...
# Processing Record 23 of Set 10 | eyl
# Processing Record 24 of Set 10 | pandan
# Processing Record 25 of Set 10 | saint-francois
# Processing Record 26 of Set 10 | tweed heads
# Processing Record 27 of Set 10 | goundi
# Processing Record 28 of Set 10 | kawalu
# Processing Record 29 of Set 10 | manda
# Processing Record 30 of Set 10 | buurhakaba
# Processing Record 31 of Set 10 | fuerte olimpo
# Processing Record 32 of Set 10 | mount isa
# Processing Record 33 of Set 10 | siddapur
# Processing Record 34 of Set 10 | inirida
# Processing Record 35 of Set 10 | broome
# Processing Record 36 of Set 10 | debre werk'
# Processing Record 37 of Set 10 | bathurst
# Processing Record 38 of Set 10 | cill airne
# Processing Record 39 of Set 10 | zahedan
# Processing Record 40 of Set 10 | taroa
# Processing Record 41 of Set 10 | nar'yan-mar
# Processing Record 42 of Set 10 | blenheim
# Processing Record 43 of Set 10 | shimoda
# Processing Record 44 of Set 10 | newnham
# Processing Record 45 of Set 10 | al wakrah
# Processing Record 46 of Set 10 | lerwick
# Processing Record 47 of Set 10 | kamen'-rybolov
# Processing Record 48 of Set 10 | semnan
# Processing Record 49 of Set 10 | fisterra
# Processing Record 0 of Set 11 | hami
# Processing Record 1 of Set 11 | mons-en-baroeul
# Processing Record 2 of Set 11 | vila franca do campo
# Processing Record 3 of Set 11 | samfya
# Processing Record 4 of Set 11 | qusmuryn
# Processing Record 5 of Set 11 | iquique
# Processing Record 6 of Set 11 | kaa-khem
# Processing Record 7 of Set 11 | argo
# Processing Record 8 of Set 11 | vilyuysk
# Processing Record 9 of Set 11 | itamaraca
# Processing Record 10 of Set 11 | coquimbo
# Processing Record 11 of Set 11 | thouars
# Processing Record 12 of Set 11 | palo santo
# Processing Record 13 of Set 11 | sittwe
# Processing Record 14 of Set 11 | malabar
# Processing Record 15 of Set 11 | padangsidempuan
# Processing Record 16 of Set 11 | phongsali
# Processing Record 17 of Set 11 | someshwar
# Processing Record 18 of Set 11 | portland
# Processing Record 19 of Set 11 | nurota
# Processing Record 20 of Set 11 | ambon
# Processing Record 21 of Set 11 | aykhal
# Processing Record 22 of Set 11 | gallup
# Processing Record 23 of Set 11 | igarka
# Processing Record 24 of Set 11 | holualoa
# Processing Record 25 of Set 11 | touros
# Processing Record 26 of Set 11 | ngereklmadel
# Processing Record 27 of Set 11 | dampit
# Processing Record 28 of Set 11 | mwene-ditu
# Processing Record 29 of Set 11 | sheksna
# Processing Record 30 of Set 11 | puerto francisco de orellana
# Processing Record 31 of Set 11 | meadow lakes
# Processing Record 32 of Set 11 | mamadysh
# Processing Record 33 of Set 11 | beledweyne
# Processing Record 34 of Set 11 | badger
# Processing Record 35 of Set 11 | conduaga
# Processing Record 36 of Set 11 | las tablas
# Processing Record 37 of Set 11 | kalisz
# Processing Record 38 of Set 11 | shangrao
# Processing Record 39 of Set 11 | dakoro
# Processing Record 40 of Set 11 | tarazona
# Processing Record 41 of Set 11 | beytussebap
# Processing Record 42 of Set 11 | gamay
# Processing Record 43 of Set 11 | shagonar
# Processing Record 44 of Set 11 | coyhaique
# Processing Record 45 of Set 11 | fortuna
# Processing Record 46 of Set 11 | liaozhong
# Processing Record 47 of Set 11 | lacin
# Processing Record 48 of Set 11 | beeville
# Processing Record 49 of Set 11 | sarupathar
# Processing Record 0 of Set 12 | la foa
# Processing Record 1 of Set 12 | ivdel'
# Processing Record 2 of Set 12 | wenling
# Processing Record 3 of Set 12 | toktogul
# Processing Record 4 of Set 12 | ts'q'alt'ubo
# Processing Record 5 of Set 12 | cockburn town
# Processing Record 6 of Set 12 | santa terezinha
# Processing Record 7 of Set 12 | rio grande
# Processing Record 8 of Set 12 | razumnoye
# Processing Record 9 of Set 12 | sept-iles
# Processing Record 10 of Set 12 | timbiqui
# Processing Record 11 of Set 12 | sibay
# Processing Record 12 of Set 12 | wattegama
# Processing Record 13 of Set 12 | dalandzadgad
# Processing Record 14 of Set 12 | edson
# Processing Record 15 of Set 12 | lubango
# Processing Record 16 of Set 12 | aitape
# Processing Record 17 of Set 12 | at-bashi
# Processing Record 18 of Set 12 | as sulayyil
# Processing Record 19 of Set 12 | arawa
# Processing Record 20 of Set 12 | nyamira
# Processing Record 21 of Set 12 | emlichheim
# Processing Record 22 of Set 12 | logansport
# Processing Record 23 of Set 12 | meulaboh
# Processing Record 24 of Set 12 | wewak
# Processing Record 25 of Set 12 | san andres
# Processing Record 26 of Set 12 | san juan de miraflores
# Processing Record 27 of Set 12 | riohacha
# Processing Record 28 of Set 12 | vingt cinq
# City not found. Skipping...
# Processing Record 29 of Set 12 | antofagasta
# Processing Record 30 of Set 12 | loango
# Processing Record 31 of Set 12 | gustavsberg
# Processing Record 32 of Set 12 | kinablangan
# Processing Record 33 of Set 12 | nan
# Processing Record 34 of Set 12 | tindouf
# Processing Record 35 of Set 12 | mezhdurechenskiy
# Processing Record 36 of Set 12 | sovetskiy
# Processing Record 37 of Set 12 | ibshaway
# Processing Record 38 of Set 12 | marsabit
# Processing Record 39 of Set 12 | sola
# Processing Record 40 of Set 12 | bestobe
# Processing Record 41 of Set 12 | tiquipaya
# Processing Record 42 of Set 12 | saratamata
# City not found. Skipping...
# Processing Record 43 of Set 12 | bireun
# Processing Record 44 of Set 12 | bich'vinta
# Processing Record 45 of Set 12 | coronel dorrego
# Processing Record 46 of Set 12 | alto barinas
# Processing Record 47 of Set 12 | batticaloa
# Processing Record 48 of Set 12 | chibougamau
# Processing Record 49 of Set 12 | myeik
# Processing Record 0 of Set 13 | pacific grove
# Processing Record 1 of Set 13 | tanrake village
# City not found. Skipping...
# Processing Record 2 of Set 13 | labe
# Processing Record 3 of Set 13 | arteche
# Processing Record 4 of Set 13 | kasungu
# Processing Record 5 of Set 13 | namibe
# Processing Record 6 of Set 13 | namtsy
# Processing Record 7 of Set 13 | port saint john's
# Processing Record 8 of Set 13 | hirara
# Processing Record 9 of Set 13 | sarina
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# Show Record Count
city_data_df.count()
# Out:
# City          581
# Lat           581
# Lng           581
# Max Temp      581
# Humidity      581
# Cloudiness    581
# Wind Speed    581
# Country       581
# Date          581
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#          City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0    keflavik  64.0049  -22.5624    277.39        75          75       15.95
# 1  bredasdorp -34.5322   20.0403    295.82        49          10        6.82
# 2      albany  42.6001  -73.9662    278.47        75          11        3.00
# 3      saipan  15.1355  145.7010    300.54        83          75        6.69
# 4     college  64.8569 -147.8028    241.12        71          75        0.00
#
#   Country        Date
# 0      IS  1702647571
# 1      ZA  1702647571
# 2      US  1702647572
# 3      MP  1702647573
# 4      US  1702647574

# %%
# Export the City_Data into a csv
city_data_df.to_csv("output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0          keflavik  64.0049  -22.5624    277.39        75          75
# 1        bredasdorp -34.5322   20.0403    295.82        49          10
# 2            albany  42.6001  -73.9662    278.47        75          11
# 3            saipan  15.1355  145.7010    300.54        83          75
# 4           college  64.8569 -147.8028    241.12        71          75
#
#          Wind Speed Country        Date
# City_ID
# 0             15.95      IS  1702647571
# 1              6.82      ZA  1702647571
# 2              3.00      US  1702647572
# 3              6.69      MP  1702647573
# 4              0.00      US  1702647574

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
plt.scatter(city_data_df["Lat"], city_data_df["Max Temp"])

# Incorporate the other graph properties
plt.title("City Max Latitude vs. Temperature (2022-10-18)")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (C)")

# Save the figure
plt.savefig("output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
plt.scatter(city_data_df["Lat"], city_data_df["Humidity"])

# Incorporate the other graph properties
plt.title("City Latitude vs. Humidity (2022-10-18)")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")

# Save the figure
plt.savefig("output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
plt.scatter(city_data_df["Lat"], city_data_df["Cloudiness"])

# Incorporate the other graph properties
plt.title("City Latitude vs. Cloudiness (2022-10-18)")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")

# Save the figure
plt.savefig("output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
plt.scatter(city_data_df["Lat"], city_data_df["Wind Speed"])

# Incorporate the other graph properties
plt.title("City Latitude vs. Wind Speed (2022-10-18)")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (m/s)")

# Save the figure
plt.savefig("output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df = city_data_df.loc[city_data_df['Lat']>= 0]

# Display sample data
northern_hemi_df.head()
# Out:
#              City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0        keflavik  64.0049  -22.5624    277.39        75          75
# 2          albany  42.6001  -73.9662    278.47        75          11
# 3          saipan  15.1355  145.7010    300.54        83          75
# 4         college  64.8569 -147.8028    241.12        71          75
# 5         udachny  66.4167  112.4000    241.73        74          97
#
#          Wind Speed Country        Date
# City_ID
# 0             15.95      IS  1702647571
# 2              3.00      US  1702647572
# 3              6.69      MP  1702647573
# 4              0.00      US  1702647574
# 5              2.24      RU  1702647575

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df = city_data_df.loc[city_data_df["Lat"] < 0]

# Display sample data
southern_hemi_df.head()
# Out:
#                       City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 1               bredasdorp -34.5322   20.0403    295.82        49          10
# 6              banjarmasin  -3.3244  114.5910    300.23        88          99
# 9           port elizabeth -33.9180   25.5701    295.31        66          40
# 11       port-aux-francais -49.3500   70.2167    279.47        93         100
# 13               grytviken -54.2811  -36.5092    277.68        68         100
#
#          Wind Speed Country        Date
# City_ID
# 1              6.82      ZA  1702647571
# 6              0.58      ID  1702647576
# 9              5.66      ZA  1702647579
# 11            12.32      TF  1702647580
# 13             3.28      GS  1702647582

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
x_values = northern_hemi_df["Lat"].astype("float")
y_values = northern_hemi_df["Max Temp"].astype("float")

# Incorporate the other graph properties
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Plot scatter plot
plt.scatter(x_values,y_values)

# Plot regression line
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")

# Label plot
plt.xlabel('Latitude')
plt.ylabel('Max Temp')

# Print r square value
print(f"The r-value is: {rvalue**2}")

# Show plot
plt.show()
# Out:
# The r-value is: 0.7356731707803358

# %%
# Linear regression on Southern Hemisphere
x_values = southern_hemi_df["Lat"].astype("float")
y_values = southern_hemi_df["Max Temp"].astype("float")

# Incorporate the other graph properties
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Plot scatter plot
plt.scatter(x_values,y_values)

# Plot regression line
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")

# Label plot
plt.xlabel('Latitude')
plt.ylabel('Max Temp')

# Print r square value
print(f"The r-value is: {rvalue**2}")

# Show plot
plt.show()
# Out:
# The r-value is: 0.4471665080333471

# %% [markdown]
# There's a positive linear trend

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = northern_hemi_df["Lat"].astype("float")
y_values = northern_hemi_df["Humidity"].astype("float")

# Incorporate the other graph properties
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Plot scatter plot
plt.scatter(x_values,y_values)

# Plot regression line
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")

# Label plot
plt.xlabel('Latitude')
plt.ylabel('Max Temp')

# Print r square value
print(f"The r-value is: {rvalue**2}")

# Show plot
plt.show()
# Out:
# The r-value is: 0.1473918068038802

# %%
# Southern Hemisphere
x_values = southern_hemi_df["Lat"].astype("float")
y_values = southern_hemi_df["Humidity"].astype("float")

# Incorporate the other graph properties
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Plot scatter plot
plt.scatter(x_values,y_values)

# Plot regression line
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")

# Label plot
plt.xlabel('Latitude')
plt.ylabel('Max Temp')

# Print r square value
print(f"The r-value is: {rvalue**2}")

# Show plot
plt.show()
# Out:
# The r-value is: 0.0019246741884831565

# %% [markdown]
# There's a positive linear trend

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = northern_hemi_df["Lat"].astype("float")
y_values = northern_hemi_df["Cloudiness"].astype("float")

# Incorporate the other graph properties
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Plot scatter plot
plt.scatter(x_values,y_values)

# Plot regression line
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")

# Label plot
plt.xlabel('Latitude')
plt.ylabel('Max Temp')

# Print r square value
print(f"The r-value is: {rvalue**2}")

# Show plot
plt.show()
# Out:
# The r-value is: 0.009246312907551164

# %%
# Southern Hemisphere
x_values = southern_hemi_df["Lat"].astype("float")
y_values = southern_hemi_df["Cloudiness"].astype("float")

# Incorporate the other graph properties
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Plot scatter plot
plt.scatter(x_values,y_values)

# Plot regression line
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")

# Label plot
plt.xlabel('Latitude')
plt.ylabel('Max Temp')

# Print r square value
print(f"The r-value is: {rvalue**2}")

# Show plot
plt.show()
# Out:
# The r-value is: 0.04064617743524418

# %% [markdown]
# There's a positive linear trend

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = northern_hemi_df["Lat"].astype("float")
y_values = northern_hemi_df["Wind Speed"].astype("float")

# Incorporate the other graph properties
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Plot scatter plot
plt.scatter(x_values,y_values)

# Plot regression line
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")

# Label plot
plt.xlabel('Latitude')
plt.ylabel('Max Temp')

# Print r square value
print(f"The r-value is: {rvalue**2}")

# Show plot
plt.show()
# Out:
# The r-value is: 6.825857421418755e-05

# %%
# Southern Hemisphere
x_values = southern_hemi_df["Lat"].astype("float")
y_values = southern_hemi_df["Wind Speed"].astype("float")

# Incorporate the other graph properties
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Plot scatter plot
plt.scatter(x_values,y_values)

# Plot regression line
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")

# Label plot
plt.xlabel('Latitude')
plt.ylabel('Max Temp')

# Print r square value
print(f"The r-value is: {rvalue**2}")

# Show plot
plt.show()
# Out:
# The r-value is: 0.04347626492413558

# %% [markdown]
# There's a positive linear trend
